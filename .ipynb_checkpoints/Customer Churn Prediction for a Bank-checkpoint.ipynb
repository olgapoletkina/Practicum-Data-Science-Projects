# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-preparation" data-toc-modified-id="Data-preparation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data preparation</a></span></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#One-Hot-Encoding" data-toc-modified-id="One-Hot-Encoding-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>One-Hot Encoding</a></span></li><li><span><a href="#Масштабируем-непрерывные-признаки-с-помощью-StandardScaler()." data-toc-modified-id="Масштабируем-непрерывные-признаки-с-помощью-StandardScaler().-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Масштабируем непрерывные признаки с помощью StandardScaler().</a></span></li><li><span><a href="#Проверяем-баланс-данных-в-колонке-'exited'" data-toc-modified-id="Проверяем-баланс-данных-в-колонке-'exited'-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Проверяем баланс данных в колонке 'exited'</a></span></li><li><span><a href="#Обучаем-несбалансированные-данные" data-toc-modified-id="Обучаем-несбалансированные-данные-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обучаем несбалансированные данные</a></span></li></ul></li><li><span><a href="#Работа-с-дисбалансом" data-toc-modified-id="Работа-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Работа с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#class_weights='balanced'" data-toc-modified-id="class_weights='balanced'-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>class_weights='balanced'</a></span></li><li><span><a href="#Upsampling,-увеличение-выборки" data-toc-modified-id="Upsampling,-увеличение-выборки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Upsampling, увеличение выборки</a></span></li><li><span><a href="#Downsampling,-уменьшение-выборки" data-toc-modified-id="Downsampling,-уменьшение-выборки-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Downsampling, уменьшение выборки</a></span></li><li><span><a href="#Выбор-лучшей-модели" data-toc-modified-id="Выбор-лучшей-модели-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Выбор лучшей модели</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li><li><span><a href="#Общий-вывод-по-проекту" data-toc-modified-id="Общий-вывод-по-проекту-7"><span class="toc-item-num">7&nbsp;&nbsp;</span><b>Общий вывод по проекту</b></a></span></li><li><span><a href="#Общий-вывод-по-проекту-В2" data-toc-modified-id="Общий-вывод-по-проекту-В2-8"><span class="toc-item-num">8&nbsp;&nbsp;</span><b>Общий вывод по проекту В2</b></a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# **Customer Churn Prediction for a Bank**
#
# **Project Overview**
#
# Customers have been leaving a certain bank. The exodus is gradual but noticeable every month. Bank marketers have determined that retaining existing customers is cheaper than attracting new ones.
#
# **Objective**
#
# The task is to predict whether a customer will leave the bank in the near future. Historical data on customer behavior and contract terminations with the bank are provided for this purpose.
#
# **Model Building**
#
# - Develop a model to achieve the highest possible *F1 Score*. The project's success criteria require reaching an F1 Score of at least 0.59.
# - Evaluate the model's performance using the *F1 Score* on the test set independently.
#
# **Additional Evaluation**
#
# - Additionally, measure the *AUC-ROC* metric and compare its value with the *F1 Score*.
#
# **Data Source**
#
# The dataset can be found at [Kaggle: Bank Customer Churn Modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling).

# %% [markdown]
# ## Data preparation

# %%
# pip install phik

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import plotly.express as px
import matplotlib.pyplot as plt

import warnings
import math

from scipy import stats as st
from scipy.spatial.distance import pdist, squareform

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder 
from sklearn.preprocessing import OneHotEncoder

from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score 
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve 
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

from sklearn.impute import SimpleImputer

from sklearn.utils import shuffle

from sklearn.model_selection import train_test_split

from joblib import dump

import phik
from phik.report import plot_correlation_matrix
from phik import report

# %%
try:
    data = pd.read_csv('/datasets/Churn.csv')
except:
    data = pd.read_csv(r"C:\Users\olga.poletkina\OneDrive - HPP Architekten GmbH\GitHub\Practicum_Data_Science\datasets\Churn.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# **There are gaps in Tenure column**

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.columns.to_series().groupby(data.dtypes).groups
# Out:
# {int64: ['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'Exited'], float64: ['Tenure', 'Balance', 'EstimatedSalary'], object: ['Surname', 'Geography', 'Gender']}

# %% [markdown]
# <b>Таблица содержит 14 столбцов с параметрами клиентов.<b>
#
# <b>Признаки:<b>
# - RowNumber — индекс строки в данных
# - CustomerId — уникальный идентификатор клиента
# - Surname — фамилия
# - CreditScore — кредитный рейтинг
# - Geography — страна проживания
# - Gender — пол
# - Age — возраст
# - Tenure — сколько лет человек является клиентом банка
# - Balance — баланс на счёте
# - NumOfProducts — количество продуктов банка, используемых клиентом
# - HasCrCard — наличие кредитной карты
# - IsActiveMember — активность клиента
# - EstimatedSalary — предполагаемая зарплата
#
# <b>Целевой признак:<b>
# - Exited — факт ухода клиента
#
# <b>В таблице 10 тыс. строк, пропуски обнаружены только в столбце Tenure. <b>
#
# <b>Очевидные дупликаты не выявлены. <b>
#
# <b>В столбца 'RowNumber', 'CustomerId', 'CreditScore', 'Age', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'Exited' типом данных является int; 'Tenure', 'Balance', 'EstimatedSalary' - float, оставшиеся признаки относятся к типу obj(str).<b>

# %%
def add_underscore(name):
    new_name = ''
    for i, char in enumerate(name):
        if i > 0 and char.isupper() and name[i-1].islower():
            new_name += '_'
        new_name += char
    return new_name

new_columns = {col: add_underscore(col) for col in data.columns}

data = data.rename(columns=new_columns)
data.head()
# Out:
#    Row_Number  Customer_Id   Surname  Credit_Score Geography  Gender  Age  \
# 0           1     15634602  Hargrave           619    France  Female   42
# 1           2     15647311      Hill           608     Spain  Female   41
# 2           3     15619304      Onio           502    France  Female   42
# 3           4     15701354      Boni           699    France  Female   39
# 4           5     15737888  Mitchell           850     Spain  Female   43
#
#    Tenure    Balance  Num_Of_Products  Has_Cr_Card  Is_Active_Member  \
# 0     2.0       0.00                1            1                 1
# 1     1.0   83807.86                1            0                 1
# 2     8.0  159660.80                3            1                 0
# 3     1.0       0.00                2            0                 0
# 4     2.0  125510.82                1            1                 1
#
#    Estimated_Salary  Exited
# 0         101348.88       1
# 1         112542.58       0
# ...

# %%
data.columns = data.columns.str.strip().str.lower()
data.head()
# Out:
#    row_number  customer_id   surname  credit_score geography  gender  age  \
# 0           1     15634602  Hargrave           619    France  Female   42
# 1           2     15647311      Hill           608     Spain  Female   41
# 2           3     15619304      Onio           502    France  Female   42
# 3           4     15701354      Boni           699    France  Female   39
# 4           5     15737888  Mitchell           850     Spain  Female   43
#
#    tenure    balance  num_of_products  has_cr_card  is_active_member  \
# 0     2.0       0.00                1            1                 1
# 1     1.0   83807.86                1            0                 1
# 2     8.0  159660.80                3            1                 0
# 3     1.0       0.00                2            0                 0
# 4     2.0  125510.82                1            1                 1
#
#    estimated_salary  exited
# 0         101348.88       1
# 1         112542.58       0
# ...

# %%
data = data.drop(columns=['row_number', 'surname'])

# %% [markdown]
# **The row_number and surname columns have been removed, the surname is no longer necessary because client could be identified by ID, column names are following PEP8.**

# %%
data['geography'] = data['geography'].str.lower()
data['gender'] = data['gender'].str.lower()
print(data['geography'].unique())
print(data['gender'].unique())
# Out:
# ['france' 'spain' 'germany']
# ['female' 'male']

# %% [markdown]
# **Оставшиеся категориальные признаки приведены к строчным.**

# %% [markdown]
# **The remaining categorical features are reduced to lowercase.**

# %%
print('Всего в в столбце tenure пропущено около {} % данных'.format(data['tenure'].isna().sum() / len(data) * 100))
# Out:
# Всего в в столбце tenure пропущено около 9.09 % данных

# %%
print(data['tenure'].describe())

data.groupby('tenure')['tenure'].count().plot(
    kind='bar', 
    grid=True,
    rot=90,
    figsize=(10, 3)
);
# Out:
# count    9091.000000
# mean        4.997690
# std         2.894723
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%         7.000000
# max        10.000000
# Name: tenure, dtype: float64

# %%
pd.plotting.scatter_matrix(data, figsize=(15, 15));

# %%
# %%script echo skipping
#
# data.corr()
# plt.figure(figsize=(20, 10))
# heatmap = sns.heatmap(data.corr(), annot=True)
# heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);
# Out:
# Couldn't find program: 'echo'

# %% [markdown]
# https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7

# %%
phik_matrix = data.phik_matrix();
plt.figure(figsize=(20, 10))
heatmap = sns.heatmap(data.phik_matrix(), annot=True);
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);
# Out:
# interval columns not set, guessing: ['customer_id', 'credit_score', 'age', 'tenure', 'balance', 'num_of_products', 'has_cr_card', 'is_active_member', 'estimated_salary', 'exited']
# interval columns not set, guessing: ['customer_id', 'credit_score', 'age', 'tenure', 'balance', 'num_of_products', 'has_cr_card', 'is_active_member', 'estimated_salary', 'exited']

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Спасибо за phik_matrix!!!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет🤔: </b>
#
# Тут смотри какой нюанс нельзя использовать корреляцию Пирсона/Спирмана для качественных признаков, а в нашем датасете есть такие признаки. Поэтому я могу предложить тебе использовать phik_matrix (https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍 В2:</b>
#
# Рад был помочь)
#
# </div>

# %% [markdown]
# https://loginom.ru/blog/missing

# %% [markdown]
# **Всего в колонке 'tenure' пропущено около 9% данных, медианное значение равно 5, а клиенты, которые пользуются услугами банка в период от 1 до 9 лет распределены приблизительно равномерно. На scatter_matrix не видно корреляций данного признака с другими.**
#
# **Для заполнения пропусков было приянто решение использовать медианные значения.**

# %%
data['tenure'] = data['tenure'].fillna(data['tenure'].median())

print(data['tenure'].describe())

data.groupby('tenure')['tenure'].count().plot(
    kind='bar', 
    grid=True,
    rot=90,
    figsize=(10, 3)
);

plt.show()

data[['tenure']].boxplot(
    figsize=(15, 3),
    vert=False, 
    rot=90, 
    fontsize=10,
);
# Out:
# count    10000.00000
# mean         4.99790
# std          2.76001
# min          0.00000
# 25%          3.00000
# 50%          5.00000
# 75%          7.00000
# max         10.00000
# Name: tenure, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍:</b>
#
# Молодчина, проблема с пропусками решена - так держать!
# </div>

# %%
data['tenure'] = data['tenure'].astype(int)

# %%
print(data['balance'].describe())
data['balance'].hist(
    bins=50,
    figsize=(5, 3)
);
plt.show()

data[['balance']].boxplot(
    figsize=(15, 3),
    vert=False, 
    rot=90, 
    fontsize=10,
);
# Out:
# count     10000.000000
# mean      76485.889288
# std       62397.405202
# min           0.000000
# 25%           0.000000
# 50%       97198.540000
# 75%      127644.240000
# max      250898.090000
# Name: balance, dtype: float64

# %%
print(data['credit_score'].describe())

data['credit_score'].hist(
    bins=50,
    figsize=(5, 3)
);
plt.show()

data[['credit_score']].boxplot(
    figsize=(15, 3),
    vert=False, 
    rot=90, 
    fontsize=10,
);
# Out:
# count    10000.000000
# mean       650.528800
# std         96.653299
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: credit_score, dtype: float64

# %%
print(data['age'].describe())

data['age'].hist(
    bins=50,
    figsize=(5, 3)
);
plt.show()

data[['age']].boxplot(
    figsize=(15, 3),
    vert=False, 
    rot=90, 
    fontsize=10,
);
# Out:
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: age, dtype: float64

# %%
print(data['estimated_salary'].describe())

data['estimated_salary'].hist(
    bins=50,
    figsize=(5, 3),
);
plt.xticks(rotation=90)
plt.show()

data[['estimated_salary']].boxplot(
    figsize=(15, 3),
    vert=False, 
    rot=90, 
    fontsize=10,
);
# Out:
# count     10000.000000
# mean     100090.239881
# std       57510.492818
# min          11.580000
# 25%       51002.110000
# 50%      100193.915000
# 75%      149388.247500
# max      199992.480000
# Name: estimated_salary, dtype: float64

# %% [markdown]
# **По scatter_matrix приходим к следующим выводам:**
# - более 3500 имеют 'balance' равный нулю, в остальном - распределение похоже на нормальное.
# - распределение кредитного рейтинга близко к нормальному.
# - основными клиентами банка являются люди до 62 лет.
# - данные по предполагаемой зарплате распределены равномерно.
# - данные в 'numofproducts' распределены биномиально.
# - данные в 'hascrcard', 'isactivemember', 'exited' имеют распределение бернулли.
# - значительных корреляций признаков в таблице выявлено не было.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍:</b>
#
# Хорошую картину построила, мое почтение!
# </div>

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### One-Hot Encoding

# %% [markdown]
# **Для решения задачи классификации нам подойдет техника обработки данных One-Hot Encoding. Затем разбиваем данные на train, valid, test.**

# %%
# %%script echo skipping
#
# data_ohe = pd.get_dummies(data, drop_first=True)
#
# target = data_ohe['exited']
# features = data_ohe.drop(['customer_id','exited'], axis=1)
#
# features_train, features_valid, target_train, target_valid = train_test_split(
#     features,
#     target,
#     test_size=0.40,
#     random_state=12345)
#
# features_test, features_valid, target_test, target_valid = train_test_split(
#     features_valid,
#     target_valid,
#     test_size=0.50,
#     random_state=12345)
#
# print(features_train.shape)
# print(target_train.shape)
# print(features_valid.shape)
# print(target_valid.shape)
# print(features_test.shape)
# print(target_test.shape)
# Out:
# Couldn't find program: 'echo'

# %%
# %%script echo skipping

target = data['exited']
features = data.drop(['customer_id','exited'], axis=1)

features_train, features_valid, target_train, target_valid = train_test_split(
    features, 
    target, 
    test_size=0.40, 
    random_state=12345)

features_test, features_valid, target_test, target_valid = train_test_split(
    features_valid, 
    target_valid, 
    test_size=0.50, 
    random_state=12345) 

print(features_train.shape)
print(target_train.shape)
print(features_valid.shape)
print(target_valid.shape)
print(features_test.shape)
print(target_test.shape)
# Out:
# (6000, 10)
# (6000,)
# (2000, 10)
# (2000,)
# (2000, 10)
# (2000,)

# %%
# %%script echo skipping

warnings.filterwarnings("ignore")
# features
ohe_features = features_train.select_dtypes(include='object').columns.to_list()
# encoder
encoder_ohe = OneHotEncoder(drop='first', handle_unknown='ignore', sparse=False)

encoder_ohe.fit(features_train[ohe_features])
# transform
features_train[encoder_ohe.get_feature_names_out()] = encoder_ohe.transform(features_train[ohe_features])
features_valid[encoder_ohe.get_feature_names_out()] = encoder_ohe.transform(features_valid[ohe_features])
features_test[encoder_ohe.get_feature_names_out()] = encoder_ohe.transform(features_test[ohe_features])
# drop columns
features_train = features_train.drop(ohe_features, axis=1)
features_valid = features_valid.drop(ohe_features, axis=1)
features_test = features_test.drop(ohe_features, axis=1)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> преобразование данных с OneHotEncoder

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍 В2:</b>
#
# Прекрасно, ты классно справилась, мало кто сразу улавливает как работать с данным методом, молодец!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍:</b>
#
# Данные поделены, замечательно! Плюсом также является проверка размеров выборки, молодец
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет🤔: </b>
#
# Смотри, ты используешь get_dummies, но ведь есть в sklearn гораздно более эффективный метод, который работает по такому же алгоритму - OHE (https://albertum.medium.com/preprocessing-onehotencoder-vs-pandas-get-dummies-3de1f3d77dcc). Если смотреть на работу внутри библиотеки sklearn, то get_dummies подходит для анализа данных, а для машинного обучения более предпочтителен OHE, т.к. он позоволяет избежать ряда ошибок при обучении моделей
#
# Также по поводу преобразования всего датасета, а не по частям - кодирование всего датасета некорректно, т.к. мы не знаем какие категории попадут в готовую модель и не будет ли там категорий, которых не было в трейне (именно в нашем проекте такого момента нет, но мы, как будущие профи, должны рассматривать все возможные случаи). Также хотел бы сразу предупредить тебя в том, что преобразуем после деления на выборки только тогда, когда используем OneHotEncoding. Применяя get_dummies, ты должен использовать данный метод сразу ко всему датасету. В будущих проектах будет приниматься только OHE и только после разделения на выборки, поэтому запомни этот совет)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# А как пользоваться SimpleImputer так что бы работало. Я использовала медиану выше, потому что он у меня здесь не сработал :-)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет🤔: </b>
#
# Хмм, у вас вроде будет эта тема потом, поэтому пока рассказывать не стоит). Могу сказать, что решение с медианой в проекте больше подойдет
# </div>

# %%
# %%script echo skipping
#
# imputer = SimpleImputer(strategy='median')
# imputer.fit(features_train)
# features_train = imputer.transform(features_train)
# features_valid = imputer.transform(features_valid)
# features_test = imputer.transform(features_test)
#
# data['tenure'].unique()
# Out:
# Couldn't find program: 'echo'

# %%
# data_ohe.head()

# %% [markdown]
# ### Масштабируем непрерывные признаки с помощью StandardScaler().

# %%
print(data.num_of_products.unique())
print(data.tenure.unique())
# Out:
# [1 3 2 4]
# [ 2  1  8  7  4  6  3 10  5  9  0]

# %%
numeric = ['credit_score', 'age', 'tenure', 'balance', 'estimated_salary', 'num_of_products']

scaler = StandardScaler()
scaler.fit(features_train[numeric])
features_train[numeric] = scaler.transform(features_train[numeric])
features_valid[numeric] = scaler.transform(features_valid[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

print(features_train.shape) 
print(features_valid.shape) 
print(features_test.shape)
# Out:
# (6000, 11)
# (2000, 11)
# (2000, 11)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍:</b>
#
# Грамотное применение масштабирование признаков, превосходно. Кстати, касательно категориальных признаков (если ты применишь алгоритм OHE из sklearn) - они преобразовываются по такому же алгоритму действий
# </div>

# %%
features_train.head()
# Out:
#       credit_score       age    tenure   balance  num_of_products  \
# 7479     -0.886751 -0.373192  1.082277  1.232271        -0.891560
# 3411      0.608663 -0.183385  1.082277  0.600563        -0.891560
# 6027      2.052152  0.480939 -0.737696  1.027098         0.830152
# 1247     -1.457915 -1.417129  0.354288 -1.233163         0.830152
# 3716      0.130961 -1.132419 -1.101690  1.140475        -0.891560
#
#       has_cr_card  is_active_member  estimated_salary  geography_germany  \
# 7479            1                 0         -0.187705                0.0
# 3411            0                 0         -0.333945                0.0
# 6027            0                 1          1.503095                1.0
# 1247            1                 0         -1.071061                0.0
# 3716            0                 0          1.524268                1.0
#
#       geography_spain  gender_male
# 7479              1.0          1.0
# 3411              0.0          0.0
# ...

# %% [markdown]
# ### Проверяем баланс данных в колонке 'exited'

# %%
class_frequency = data['exited'].value_counts(normalize=True)
print(class_frequency)
print()
print('Отрицательных значений больше положительных в {} раза'.format(round(class_frequency[0]/class_frequency[1])))
class_frequency.plot(kind='bar');
# Out:
# 0    0.7963
# 1    0.2037
# Name: exited, dtype: float64
#
# Отрицательных значений больше положительных в 4 раза

# %% [markdown]
# **Проверка баланса показывает, что положительные значения составляют около 20% от общего числа. В данных есть дисбаланс.**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍:</b>
#
# Да, дисбаланс у нас такой, многовато))
# </div>

# %% [markdown]
# ### Обучаем несбалансированные данные

# %% [markdown]
# **DecisionTreeClassifier**

# %%
model_dtc = DecisionTreeClassifier(random_state=12345)
model_dtc.fit(features_train, target_train)

predicted_valid_dtc = model_dtc.predict(features_valid)
accuracy_valid_dtc = accuracy_score(target_valid, predicted_valid_dtc)

print('Accuracy:',accuracy_valid_dtc)
print('Recall:',recall_score(target_valid, predicted_valid_dtc))
print('Precision:',precision_score(target_valid, predicted_valid_dtc))
print('F1:',f1_score(target_valid, predicted_valid_dtc))
confusion_matrix(target_valid, predicted_valid_dtc)
# Out:
# Accuracy: 0.7865
# Recall: 0.458628841607565
# Precision: 0.49489795918367346
# F1: 0.4760736196319018
# array([[1379,  198],
#        [ 229,  194]], dtype=int64)

# %% [markdown]
# **RandomForestClassifier**

# %%
model_rfc = RandomForestClassifier(random_state=12345)
model_rfc.fit(features_train, target_train)

predicted_valid_rfc = model_rfc.predict(features_valid)
accuracy_valid_rfc = accuracy_score(target_valid, predicted_valid_rfc)

print('Accuracy:',accuracy_valid_rfc)
print('Recall:',recall_score(target_valid, predicted_valid_rfc))
print('Precision:',precision_score(target_valid, predicted_valid_rfc))
print('F1:',f1_score(target_valid, predicted_valid_rfc))
confusion_matrix(target_valid, predicted_valid_rfc)
# Out:
# Accuracy: 0.8495
# Recall: 0.4302600472813239
# Precision: 0.7520661157024794
# F1: 0.5473684210526315
# array([[1517,   60],
#        [ 241,  182]], dtype=int64)

# %% [markdown]
# **LogisticRegression**

# %%
model_lr = LogisticRegression(random_state=12345, solver='liblinear')
model_lr.fit(features_train, target_train)

predicted_valid_lr = model_lr.predict(features_valid)
accuracy_valid_lr = accuracy_score(target_valid, predicted_valid_lr)

print('Accuracy:',accuracy_valid_lr)
print('Recall:',recall_score(target_valid, predicted_valid_lr))
print('Precision:',precision_score(target_valid, predicted_valid_lr))
print('F1:',f1_score(target_valid, predicted_valid_lr))
confusion_matrix(target_valid, predicted_valid_lr)
# Out:
# Accuracy: 0.7915
# Recall: 0.1867612293144208
# Precision: 0.5197368421052632
# F1: 0.27478260869565213
# array([[1504,   73],
#        [ 344,   79]], dtype=int64)

# %%
probabilities_valid_dtc = model_dtc.predict_proba(features_valid)
# print(probabilities_valid_dtc)
probabilities_one_valid_dtc = probabilities_valid_dtc[:, 1]

probabilities_valid_rfc = model_rfc.predict_proba(features_valid)
probabilities_one_valid_rfc = probabilities_valid_rfc[:, 1]

probabilities_valid_lr = model_lr.predict_proba(features_valid)
probabilities_one_valid_lr = probabilities_valid_lr[:, 1]

fpr_dtc, tpr_dtc, thresholds = roc_curve(target_valid, probabilities_one_valid_dtc) 
fpr_rfc, tpr_rfc, thresholds = roc_curve(target_valid, probabilities_one_valid_rfc) 
fpr_lr, tpr_lr, thresholds = roc_curve(target_valid, probabilities_one_valid_lr)

print('Area Under Curve ROC_dtc:', roc_auc_score(target_valid, probabilities_one_valid_dtc))
print('Area Under Curve ROC_rfc:', roc_auc_score(target_valid, probabilities_one_valid_rfc))
print('Area Under Curve ROC_lr:', roc_auc_score(target_valid, probabilities_one_valid_lr))

plt.figure()

plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(fpr_dtc, tpr_dtc)
plt.plot(fpr_rfc, tpr_rfc)
plt.plot(fpr_lr, tpr_lr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend(['Random', 'DTC', 'RFC', 'LR'])
plt.show()
# Out:
# Area Under Curve ROC_dtc: 0.666536995312343
# Area Under Curve ROC_rfc: 0.8499762394107974
# Area Under Curve ROC_lr: 0.7386410142248726

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b>
# Я немного запуталась, почему на несбалансированной моделе без подбора гиперпараметров predict_proba выдает не вероятности, а нули и единицы. График получается триугольный, в моделях ниже пробабилити предсказывается нормально...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍 В2:</b>
#
# Это все за счет того, что модели максимально простые и предсказывать нормально они не могут и твой график roc-кривой для дерева решений получается таким вот, не оченьским
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка❌:</b>
#
# Я тут заметил, что AUC-ROC метрика отсутствует - добавь ее. И не забудь про то, что она определяется по вероятностям, а не по предсказаниям.(https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html)
#
# Также не забудь про то, что ее нужно добавить к каждой модели, где ты проверяешь метрику f1, так как бизнес потребовал проверить ее тоже
#
# Также проблема с перебором гиперпараметров - его все-таки нужно будет реализовать, перебор гиперпараметров позволит нам подобрать лучшие модели, которые потом можно будет сравнить с лучшими моделями при решении дисбаланса. Перебор сделай для всех моделей!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> добавлены AUC-ROC метрики

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍 В2:</b>
#
# Все есть, молодец!
# </div>

# %% [markdown]
# **Обучая модели DecisionTreeClassifier, RandomForestClassifier и LogisticRegression на несбалансированных данных, мы получили следующие результаты:**
# - матрицы неточнойстей всех трех моделей показывают значительное количество ошибок в квадранте FN(ложноотрицательные) и FP(пожноположительные)
# - полнота, доля TP-ответов среди значений, у которых истинная метка 1, в DecisionTreeClassifier и RandomForestClassifier находится в районе 0,45-0,43, а LogisticRegression показывает очень низкое значение - 0,18
# - точность RandomForestClassifier составляет 0.75, а две оставшиеся модели показывают более низкий счет.
# - во всех моделях показатель среднего гармонического ниже необходимого уровня 0,59

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍:</b>
#
# Вывод сделала хороший - мое почтение, такой полный и точный, прямо как надо)
# </div>

# %% [markdown]
# ## Работа с дисбалансом

# %% [markdown]
# ### class_weights='balanced'

# %% [markdown]
# **DecisionTreeClassifier**

# %%
criterions = ['gini', 'entropy', 'log_loss']

best_model_dtc = None
best_f1_dtc = 0

for min_samples_split in range(2, 10):
    for depth in range(1, 10):
        for criterion in criterions:
            try:
                model_dtc = DecisionTreeClassifier(random_state=12345, min_samples_split=min_samples_split, 
                                               max_depth=depth, criterion=criterion, class_weight='balanced')
                model_dtc.fit(features_train, target_train)
    
                predictions_valid_dtc = model_dtc.predict(features_valid)
                f1_dtc = f1_score(target_valid, predictions_valid_dtc)
                if f1_dtc > best_f1_dtc:
                    best_f1_dtc = f1_dtc
                    best_model_dtc = model_dtc
            except:
                pass

print('F1 наилучшей модели :', best_f1_dtc)
print('model:', best_model_dtc)
# Out:
# F1 наилучшей модели : 0.5809128630705395
# model: DecisionTreeClassifier(class_weight='balanced', max_depth=5, random_state=12345)

# %% [markdown]
# **RandomForestClassifier**

# %%
max_features = [['sqrt', 'log2', None], [n for n in range(1, 6)]]
max_features = sum(max_features, [])

# criterions = ['gini', 'entropy', 'log_loss']

best_model_rfc = None
best_f1_rfc = 0

for max_depth in range(1, 16, 2):
    for est in range(1, 120, 20):
        for max_feature in max_features:
            for criterion in criterions:
                try:
                    model_rfc = RandomForestClassifier(random_state=12345, n_estimators=est, 
                                max_depth=max_depth, criterion=criterion, max_features=max_feature, class_weight='balanced') 
                    model_rfc.fit(features_train, target_train)

                    predictions_valid_rfc = model_rfc.predict(features_valid)
                    f1_rfc = f1_score(target_valid, predictions_valid_rfc)
                    if f1_rfc > best_f1_rfc:
                        best_f1_rfc = f1_rfc
                        best_model_rfc = model_rfc 
                except:
                    pass

print('F1 наилучшей модели :', best_f1_rfc)
print('model:', best_model_rfc)
# Out:
# F1 наилучшей модели : 0.6275720164609054
# model: RandomForestClassifier(class_weight='balanced', max_depth=7, max_features=5,
#                        n_estimators=101, random_state=12345)

# %% [markdown]
# **LogisticRegression**

# %%
warnings.filterwarnings("ignore")

solvers = ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga']
penalties = ['l1', 'l2']

best_model_lr = None
best_f1_lr = 0

for solver in solvers:
    for penalty in penalties:
        for max_iter in range(500, 5000, 500):
            try:
                model_lr = LogisticRegression(penalty=penalty, random_state=12345, solver=solver, 
                                              max_iter=1000, class_weight='balanced')
                model_lr.fit(features_train, target_train) 

                predictions_valid_lr = model_lr.predict(features_valid)
                f1_lr = f1_score(target_valid, predicted_valid_lr)
        
                if f1_lr > best_f1_lr:
                    best_f1_lr = f1_lr
                    best_model_lr = model_lr
            except:
                pass

print('F1 наилучшей модели :', best_f1_lr)
print('model:', best_model_lr)
# Out:
# F1 наилучшей модели : 0.27478260869565213
# model: LogisticRegression(class_weight='balanced', max_iter=1000, penalty='l1',
#                    random_state=12345, solver='liblinear')

# %%
model_dtc = DecisionTreeClassifier(class_weight='balanced', max_depth=5, random_state=12345)
model_dtc.fit(features_train, target_train)
probabilities_valid_dtc = model_dtc.predict_proba(features_valid)
probabilities_one_valid_dtc = probabilities_valid_dtc[:, 1]

model_rfc = RandomForestClassifier(class_weight='balanced', max_depth=7, max_features=5,
                       n_estimators=101, random_state=12345)
model_rfc.fit(features_train, target_train)
probabilities_valid_rfc = model_rfc.predict_proba(features_valid)
probabilities_one_valid_rfc = probabilities_valid_rfc[:, 1]

model_lr = LogisticRegression(class_weight='balanced', max_iter=1000, penalty='l1', random_state=12345, solver='liblinear')
model_lr.fit(features_train, target_train) 
probabilities_valid_lr = model_lr.predict_proba(features_valid)
probabilities_one_valid_lr = probabilities_valid_lr[:, 1]

fpr_dtc, tpr_dtc, thresholds = roc_curve(target_valid, probabilities_one_valid_dtc) 
fpr_rfc, tpr_rfc, thresholds = roc_curve(target_valid, probabilities_one_valid_rfc) 
fpr_lr, tpr_lr, thresholds = roc_curve(target_valid, probabilities_one_valid_lr)

print('Area Under Curve ROC_dtc:', roc_auc_score(target_valid, probabilities_one_valid_dtc))
print('Area Under Curve ROC_rfc:', roc_auc_score(target_valid, probabilities_one_valid_rfc))
print('Area Under Curve ROC_lr:', roc_auc_score(target_valid, probabilities_one_valid_lr))

plt.figure()

plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(fpr_dtc, tpr_dtc)
plt.plot(fpr_rfc, tpr_rfc)
plt.plot(fpr_lr, tpr_lr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend(['Random', 'DTC', 'RFC', 'LR'])
plt.show()
# Out:
# Area Under Curve ROC_dtc: 0.8355347481752318
# Area Under Curve ROC_rfc: 0.8621121289937652
# Area Under Curve ROC_lr: 0.7419135294443919

# %% [markdown]
# ### Upsampling, увеличение выборки

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled

features_upsampled, target_upsampled = upsample(features_train, target_train, 4)

# %% [markdown]
# **Проверяем баланс**

# %%
class_frequency = target_upsampled.value_counts(normalize=True)
print(class_frequency)
print()
print('Отрицательных значений больше положительных в {} раза'.format(round(class_frequency[0]/class_frequency[1])))
class_frequency.plot(kind='bar');
# Out:
# 0    0.501043
# 1    0.498957
# Name: exited, dtype: float64
#
# Отрицательных значений больше положительных в 1 раза

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍 В2:</b>
#
# Баланс достигнут - молодец!
# </div>

# %% [markdown]
# **Баланс достигнут**

# %% [markdown]
# **Проверяем разные модели с увеличенной выборкой**

# %% [markdown]
# **DecisionTreeClassifier**

# %%
criterions = ['gini', 'entropy', 'log_loss']

best_model_dtc = None
best_f1_dtc = 0

for min_samples_split in range(2, 10):
    for depth in range(1, 10):
        for criterion in criterions:
            try:
                model_dtc = DecisionTreeClassifier(random_state=12345, min_samples_split=min_samples_split, 
                                               max_depth=depth, criterion=criterion)
                model_dtc.fit(features_upsampled, target_upsampled)
    
                predictions_valid_dtc = model_dtc.predict(features_valid)
                f1_dtc = f1_score(target_valid, predictions_valid_dtc)
                       
                if f1_dtc > best_f1_dtc:
                    best_f1_dtc = f1_dtc
                    best_model_dtc = model_dtc
            except:
                pass

print('F1 наилучшей модели :', best_f1_dtc)
print('model:', best_model_dtc)
# Out:
# F1 наилучшей модели : 0.5809128630705395
# model: DecisionTreeClassifier(max_depth=5, random_state=12345)

# %% [markdown]
# **RandomForestClassifier**

# %%
max_features = [['sqrt', 'log2', None], [n for n in range(1, 6)]]
max_features = sum(max_features, [])

# criterions = ['gini', 'entropy', 'log_loss']

best_model_rfc = None
best_f1_rfc = 0

for max_depth in range(1, 16, 2):
    for est in range(1, 120, 20):
        for max_feature in max_features:
            for criterion in criterions:
                try:
                    model_rfc = RandomForestClassifier(random_state=12345, n_estimators=est, 
                                                   max_depth=max_depth, criterion=criterion, max_features=max_feature) 
                    model_rfc.fit(features_upsampled, target_upsampled)

                    predictions_valid_rfc = model_rfc.predict(features_valid)
                    f1_rfc = f1_score(target_valid, predictions_valid_rfc)
                    if f1_rfc > best_f1_rfc:
                        best_f1_rfc = f1_rfc
                        best_model_rfc = model_rfc 
                except:
                    pass

print('F1 наилучшей модели :', best_f1_rfc)
print('model:', best_model_rfc)
# Out:
# F1 наилучшей модели : 0.6266804550155118
# model: RandomForestClassifier(criterion='entropy', max_depth=9, max_features=4,
#                        n_estimators=81, random_state=12345)

# %% [markdown]
# **LogisticRegression**

# %%
warnings.filterwarnings("ignore")

solvers = ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga']
penalties = ['l1', 'l2']

best_model_lr = None
best_f1_lr = 0

for solver in solvers:
    for penalty in penalties:
        for max_iter in range(500, 5000, 500):
            try:
                model_lr = LogisticRegression(penalty=penalty, random_state=12345, solver=solver, max_iter=1000)
                model_lr.fit(features_upsampled, target_upsampled) 

                predictions_valid_lr = model_lr.predict(features_valid)
                f1_lr = f1_score(target_valid, predicted_valid_lr)
        
                if f1_lr > best_f1_lr:
                    best_f1_lr = f1_lr
                    best_model_lr = model_lr
            except:
                pass

print('F1 наилучшей модели :', best_f1_lr)
print('model:', best_model_lr)
# Out:
# F1 наилучшей модели : 0.27478260869565213
# model: LogisticRegression(max_iter=1000, penalty='l1', random_state=12345,
#                    solver='liblinear')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍:</b>
#
# Функция upsample реализована верно, все как надо, молодец)
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет🤔: </b>
#
# После преобразования данных, я бы проверил баланс в них, вдруг дисбаланс в них остался.
#
# Также я бы разделил ячейку на две: в первой ты будешь реализовывать функцию и менять свои данные, а во второй уже проверять модели
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Ошибка❌:</b>
#
# Однако касательно перебора гиперпараметров - его все-таки нужно будет реализовать, ведь у нас меняется структура данных, да и баланс в классах становится другим, а значит перед нами (с точки зрения машины) другие данные. Перебор гиперпараметров позволит нам подобрать лучшую модель по новым данным
#
# Ну и конечно момент связанный с применением двух методов борьбы с дисбалансом, когда нам нужно применить по одному методу, так мы сможем проверить работу каждого метода с каждой моделью и вывести лучшую. По итогу у тебя должны получиться такие комбинации:
#
# - лес с upsample
# - дерево с upsample
# - лог регрессия с upsample
# - лес с downsample
# - дерево с downsample
# - лог регрессия с downsample
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Были внесены следующие изменения:
#
#         - проверка моделей с добавлением class_weight='balanced'
#         - код по увеличению и уменьшению выборки вынесен в отдельное окно
#         - проверка всех методов на моделях с перебором гиперпараметров
#         - проверка баланса данных после up и downsampling, корректировка баланса

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍 В2:</b>
#
# Класс, ты все правильно сделала, проект становится удобнее и точнее)
# </div>

# %%
model_dtc = DecisionTreeClassifier(max_depth=5, random_state=12345)
model_dtc.fit(features_upsampled, target_upsampled)
probabilities_valid_dtc = model_dtc.predict_proba(features_valid)
probabilities_one_valid_dtc = probabilities_valid_dtc[:, 1]

model_rfc = RandomForestClassifier(criterion='entropy', max_depth=9, max_features=4, n_estimators=81, random_state=12345)
model_rfc.fit(features_upsampled, target_upsampled)
probabilities_valid_rfc = model_rfc.predict_proba(features_valid)
probabilities_one_valid_rfc = probabilities_valid_rfc[:, 1]

model_lr = LogisticRegression(max_iter=1000, penalty='l1', random_state=12345,solver='liblinear')
model_lr.fit(features_upsampled, target_upsampled) 
probabilities_valid_lr = model_lr.predict_proba(features_valid)
probabilities_one_valid_lr = probabilities_valid_lr[:, 1]

fpr_dtc, tpr_dtc, thresholds = roc_curve(target_valid, probabilities_one_valid_dtc) 
fpr_rfc, tpr_rfc, thresholds = roc_curve(target_valid, probabilities_one_valid_rfc) 
fpr_lr, tpr_lr, thresholds = roc_curve(target_valid, probabilities_one_valid_lr)

print('Area Under Curve ROC_dtc:', roc_auc_score(target_valid, probabilities_one_valid_dtc))
print('Area Under Curve ROC_rfc:', roc_auc_score(target_valid, probabilities_one_valid_rfc))
print('Area Under Curve ROC_lr:', roc_auc_score(target_valid, probabilities_one_valid_lr))

plt.figure()

plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(fpr_dtc, tpr_dtc)
plt.plot(fpr_rfc, tpr_rfc)
plt.plot(fpr_lr, tpr_lr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend(['Random', 'DTC', 'RFC', 'LR'])
plt.show()
# Out:
# Area Under Curve ROC_dtc: 0.8355347481752318
# Area Under Curve ROC_rfc: 0.8582010010928371
# Area Under Curve ROC_lr: 0.7418445712675261

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍:</b>
#
# Вот это однозначно топ, мне нравится! Сделала все очень точно, метрика идеально расписана + график есть - молодец!
# </div>

# %% [markdown]
# ### Downsampling, уменьшение выборки

# %%
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat(
        [features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat(
        [target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
    
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=12345)
    
    return features_downsampled, target_downsampled

features_downsampled, target_downsampled = downsample(features_train, target_train, 0.25)

# %% [markdown]
# **Проверяем баланс**

# %%
class_frequency = target_downsampled.value_counts(normalize=True)
print(class_frequency)
print()
print('Отрицательных значений больше положительных в {} раза'.format(round(class_frequency[0]/class_frequency[1])))
class_frequency.plot(kind='bar');
# Out:
# 0    0.501043
# 1    0.498957
# Name: exited, dtype: float64
#
# Отрицательных значений больше положительных в 1 раза

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍 В2:</b>
#
# И тут баланс есть - прекрасно
# </div>

# %% [markdown]
# **Баланс достигнут**

# %% [markdown]
# **Проверяем разные модели с уменьшенной выборкой**

# %% [markdown]
# **DecisionTreeClassifier**

# %%
criterions = ['gini', 'entropy', 'log_loss']

best_model_dtc = None
best_f1_dtc = 0

for min_samples_split in range(2, 10):
    for depth in range(1, 10):
        for criterion in criterions:
            try:
                model_dtc = DecisionTreeClassifier(random_state=12345, min_samples_split=min_samples_split, 
                                               max_depth=depth, criterion=criterion)
                model_dtc.fit(features_downsampled, target_downsampled)
    
                predictions_valid_dtc = model_dtc.predict(features_valid)
                f1_dtc = f1_score(target_valid, predictions_valid_dtc)
                       
                if f1_dtc > best_f1_dtc:
                    best_f1_dtc = f1_dtc
                    best_model_dtc = model_dtc
            except:
                pass

print('F1 наилучшей модели :', best_f1_dtc)
print('model:', best_model_dtc)
# Out:
# F1 наилучшей модели : 0.608695652173913
# model: DecisionTreeClassifier(max_depth=5, min_samples_split=3, random_state=12345)

# %% [markdown]
# **RandomForestClassifier**

# %%
max_features = [['sqrt', 'log2', None], [n for n in range(1, 6)]]
max_features = sum(max_features, [])

# criterions = ['gini', 'entropy', 'log_loss']

best_model_rfc = None
best_f1_rfc = 0

for max_depth in range(1, 16, 2):
    for est in range(1, 120, 20):
        for max_feature in max_features:
            for criterion in criterions:
                try:
                    model_rfc = RandomForestClassifier(random_state=12345, n_estimators=est, 
                                                   max_depth=max_depth, criterion=criterion, max_features=max_feature) 
                    model_rfc.fit(features_downsampled, target_downsampled)

                    predictions_valid_rfc = model_rfc.predict(features_valid)
                    f1_rfc = f1_score(target_valid, predictions_valid_rfc)
                    if f1_rfc > best_f1_rfc:
                        best_f1_rfc = f1_rfc
                        best_model_rfc = model_rfc 
                except:
                    pass

print('F1 наилучшей модели :', best_f1_rfc)
print('model:', best_model_rfc)
# Out:
# F1 наилучшей модели : 0.5998125585754451
# model: RandomForestClassifier(max_depth=7, max_features=4, n_estimators=81,
#                        random_state=12345)

# %% [markdown]
# **LogisticRegression**

# %%
warnings.filterwarnings("ignore")

solvers = ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga']
penalties = ['l1', 'l2']

best_model_lr = None
best_f1_lr = 0

for solver in solvers:
    for penalty in penalties:
        for max_iter in range(500, 5000, 500):
            try:
                model_lr = LogisticRegression(penalty=penalty, random_state=12345, solver=solver, max_iter=1000)
                model_lr.fit(features_downsampled, target_downsampled) 

                predictions_valid_lr = model_lr.predict(features_valid)
                f1_lr = f1_score(target_valid, predicted_valid_lr)
        
                if f1_lr > best_f1_lr:
                    best_f1_lr = f1_lr
                    best_model_lr = model_lr
            except:
                pass

print('F1 наилучшей модели :', best_f1_lr)
print('model:', best_model_lr)
# Out:
# F1 наилучшей модели : 0.27478260869565213
# model: LogisticRegression(max_iter=1000, penalty='l1', random_state=12345,
#                    solver='liblinear')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍:</b>
#
# Ну и функция уменьшения выборки расписана также верно, как и увеличения, так держать!
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет🤔: </b>
#
# Совет такой же
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Ошибка❌:</b>
#
# Рекомендация такая же
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍 В2:</b>
#
# Все есть)
# </div>

# %%
model_dtc = DecisionTreeClassifier(max_depth=5, min_samples_split=3, random_state=12345)
model_dtc.fit(features_downsampled, target_downsampled)
probabilities_valid_dtc = model_dtc.predict_proba(features_valid)
probabilities_one_valid_dtc = probabilities_valid_dtc[:, 1]

model_rfc = RandomForestClassifier(max_depth=7, max_features=4, n_estimators=81,random_state=12345)
model_rfc.fit(features_downsampled, target_downsampled)
probabilities_valid_rfc = model_rfc.predict_proba(features_valid)
probabilities_one_valid_rfc = probabilities_valid_rfc[:, 1]

model_lr = LogisticRegression(max_iter=1000, penalty='l1', random_state=12345, solver='liblinear')
model_lr.fit(features_downsampled, target_downsampled)
probabilities_valid_lr = model_lr.predict_proba(features_valid)
probabilities_one_valid_lr = probabilities_valid_lr[:, 1]

fpr_dtc, tpr_dtc, thresholds = roc_curve(target_valid, probabilities_one_valid_dtc) 
fpr_rfc, tpr_rfc, thresholds = roc_curve(target_valid, probabilities_one_valid_rfc) 
fpr_lr, tpr_lr, thresholds = roc_curve(target_valid, probabilities_one_valid_lr)

print('Area Under Curve ROC_dtc:', roc_auc_score(target_valid, probabilities_one_valid_dtc))
print('Area Under Curve ROC_rfc:', roc_auc_score(target_valid, probabilities_one_valid_rfc))
print('Area Under Curve ROC_lr:', roc_auc_score(target_valid, probabilities_one_valid_lr))

plt.figure()

plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(fpr_dtc, tpr_dtc)
plt.plot(fpr_rfc, tpr_rfc)
plt.plot(fpr_lr, tpr_lr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend(['Random', 'DTC', 'RFC', 'LR'])
plt.show()
# Out:
# Area Under Curve ROC_dtc: 0.8380015020889828
# Area Under Curve ROC_rfc: 0.8512542143190156
# Area Under Curve ROC_lr: 0.7416346985553263

# %% [markdown]
# **По итогам балансирования модели были сделаны следующие выводы:**
# - все три подхода - добавление баланса в вес класса, увеличение и уменьшение выборки, улучшили результаты работы моделей и показали более высокий счет F1
# - downsampling оказался эффективным для DecisionTreeClassifier, а добавленеи баланса и увеличение выборки оказались самыми эффективными в моделе RandomForestClassifier.
# - ROC кривая и показатель площади под кривой RandomForestClassifier показал самый высокий результат
# - при увеличении счета F1 увеличивается площадь под кривой ROC

# %% [markdown]
# ### Выбор лучшей модели

# %% [markdown]
# **По результатам балансировки моделей лучший результат показала RandomForestClassifier с class_weight='balanced', RandomForestClassifier с Upsampling и DecisionTreeClassifier с Downsampling. Выбираем вторую модель для проверки на тестовой выборке.**

# %%
model_rfc_cw = RandomForestClassifier(class_weight='balanced', max_depth=7, max_features=5, n_estimators=101, random_state=12345)
model_rfc_cw.fit(features_upsampled, target_upsampled)
predictions_valid_rfc_cw = model_rfc_cw.predict(features_valid)
f1_rfc = f1_score(target_valid, predictions_valid_rfc_cw)
f1_rfc
# Out:
# 0.6137040714995035

# %%
model_rfc_up = RandomForestClassifier(criterion='entropy', max_depth=9, max_features=4, n_estimators=81, random_state=12345)
model_rfc_up.fit(features_upsampled, target_upsampled)
predictions_valid_rfc_up = model_rfc_up.predict(features_valid)
f1_rfc = f1_score(target_valid, predictions_valid_rfc_up)
f1_rfc
# Out:
# 0.6266804550155118

# %%
model_dtc_down = DecisionTreeClassifier(max_depth=5, min_samples_split=3, random_state=12345)
model_dtc_down.fit(features_downsampled, target_downsampled)
predictions_valid_dtc_down = model_dtc_down.predict(features_valid)
f1_rfc = f1_score(target_valid, predictions_valid_dtc_down)
f1_rfc
# Out:
# 0.608695652173913

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет🤔: </b>
#
# Вот такие финты нужно было делать со всеми моделями, дабы проверить верно их качество)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> все комментарии учтены выше

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍 В2:</b>
#
# Все было учтено - так держать!
# </div>

# %% [markdown]
# ## Тестирование модели

# %%
final_model = model_rfc_up
final_model.fit(features_upsampled, target_upsampled)
predictions_test = final_model.predict(features_test)

f1_test = f1_score(target_test, predictions_test)
accuracy_test = accuracy_score(target_test, predictions_test)
recall = recall_score(target_test, predictions_test)
precision = precision_score(target_test, predictions_test)

print('F1 на тестовой выборке :', f1_test)
print()
print('Accuracy на тестовой выборке:', accuracy_test)
print('Recall на тестовой выборке:',recall)
print('Precision на тестовой выборке:', precision)

confusion_matrix(target_test, predictions_test)
# Out:
# F1 на тестовой выборке : 0.6215644820295984
#
# Accuracy на тестовой выборке: 0.821
# Recall на тестовой выборке: 0.7033492822966507
# Precision на тестовой выборке: 0.5568181818181818
# array([[1348,  234],
#        [ 124,  294]], dtype=int64)

# %%
probabilities_test = final_model.predict_proba(features_test)
probabilities_one_test = probabilities_test[:, 1]

fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test)

print('Area Under Curve ROC_final:', roc_auc_score(target_test, probabilities_one_test))

plt.figure()

plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(fpr, tpr)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.show()
# Out:
# Area Under Curve ROC_final: 0.8563822065219363

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍:</b>
#
# Тестирование выполнено идеально, ты прекрасно справилась с этим этапом - молодец!
# </div>

# %% [markdown]
# **По итогам исследования была выбрана модель RandomForestClassifier(criterion='entropy', max_depth=9, max_features=4, n_estimators=81, random_state=12345), которая показала счет F1 на тестовой выборке, равный 0.62, что удовлетворяет задаче. Площадь под кривой ROC равна прибл. 0.86, а показатель accuracy модели на тестовой выборке равен 0.821.**

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Меня смущает confusion matrix, как ее улучшить? Или мы это еще будем проходить в дальнейших спринтах?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет🤔: </b>
#
# Тут кроется проблема в данных и самой модели - данные искусственные, на них сложно построить хорошо рабочую, простую модель + так как модели простые у нас, то и качество у них пониже будет, чем у какой-нибудь нейронной сети с несколькими слоями. В следующих проектах вы должны будете улучшать свои навыки и перейдете к более сложным моделям)
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В проекте был проведен анализ таблицы с характеристиками клиентов банка и выбрана модель, которая показала счет F1 больше 0.59.
#
# **По результатам анализа данных следаны следующие выводы и изменения:**
#
# - не выявлены очевидные дупликаты
# - названия колонок исправлены на строчные с нижним подчеркиванием
# - колонки row_number и surname удалены, в фамилии нет необходимости т.к. клиента можно иденцифицировать по ID, названия колонок приведены к строчным буквам
# - оставшиеся категориальные признаки приведены к строчным
# - выявлены пропуски в колонке tenure, всего пропущено около 9% данных, медианное значение равно 5; клиенты, которые пользуются услугами банка в период от 1 до 9 лет распределены приблизительно равномерно. На scatter_matrix не видно корреляций данного признака с другими.
# - для заполнения пропусков было приянто решение использовать медианные значения.
# - более 3500 человек имеют 'balance' равный нулю, в остальном - распределение похоже на нормальное.
# - распределение кредитного рейтинга близко к нормальному.
# - основными клиентами банка являются люди до 62 лет.
# - данные по предполагаемой зарплате распределены равномерно.
# - данные в 'numofproducts' распределены биномиально
# - данные в 'hascrcard', 'isactivemember', 'exited' имеют распределение бернулли.
# - значительных корреляций признаков в таблице выявлено не было.
#
# **Для решения задачи классификации выбрана техника обработки данных One-Hot Encoding. Данные были разбиты на три выборки -  train, valid, test, затем обработаны с помощью OneHotEncoder. Далее данные были отмасштабированы с помощью StandardScaler().**
#
# **Далее был проверен баланс в колонке 'exited'. Проверка баланса показывает, что положительные значения составляют около 20% от общего числа. В данных есть дисбаланс.**
#
# **Затем модели классификации DecisionTreeClassifier, RandomForestClassifier и LogisticRegression были обучены на несбалансированных данных, были получены следующие результаты:**
#
# - матрицы неточнойстей всех трех моделей показывают значительное количество ошибок в квадранте FN(ложноотрицательные) и FP(пожноположительные)
# - полнота, доля TP-ответов среди значений, у которых истинная метка 1, в DecisionTreeClassifier и RandomForestClassifier находится в районе 0,45-0,43, а LogisticRegression показывает очень низкое значение - 0,18
# - точность RandomForestClassifier составляет 0.75, а две оставшиеся модели показывают более низкий счет.
# - во всех моделях показатель среднего гармонического ниже необходимого уровня 0,59
#
# **Далее данные были сбалансированы тремя способами:**
# - добавление баланса в вес класса
# - увеличение выборки
# - уменьшение выборки
#
# **По итогам были сделаны следующие выводы:**
# - все три подхода - добавление баланса в вес класса, увеличение и уменьшение выборки, улучшили результаты работы моделей и показали более высокий счет F1
# - downsampling оказался эффективным для DecisionTreeClassifier, а добавленеи баланса и увеличение выборки оказались самыми эффективными в моделе RandomForestClassifier.
# - ROC кривая и показатель площади под кривой RandomForestClassifier показал самый высокий результат
# - при увеличении счета F1 увеличивается площадь под кривой ROC
#
# **По результатам балансировки моделей лучший результат показала RandomForestClassifier с class_weight='balanced', RandomForestClassifier с Upsampling и DecisionTreeClassifier с Downsampling. Выбираем вторую модель для проверки на тестовой выборке.**
#
# **По итогам исследования была выбрана модель RandomForestClassifier(criterion='entropy', max_depth=9, max_features=4, n_estimators=81, random_state=12345), которая показала счет F1 на тестовой выборке, равный 0.62, что удовлетворяет задаче. Площадь под кривой ROC равна прибл. 0.86, а показатель accuracy модели на тестовой выборке равен 0.821.**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех👍:</b>
#
# Вывод у тебя вышел очень хорошим - он понятен, прост и информативен. Именно таким и должен быть итоговый вывод, как краткий экскурс в твой проект. Думаю ты бы уже смогла рассказывать его перед своими будущими коллегами, аналитиками и начальством, ведь писать выводы и грамотно анализировать свои действия - крайне важно для нас!
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: задача исследована
#     - [x]  Исследован баланс классов
#     - [x]  Изучены модели без учёта дисбаланса
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 3: учтён дисбаланс
#     - [x]  Применено несколько способов борьбы с дисбалансом
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 4: проведено тестирование
# - [x]  Удалось достичь *F1*-меры не менее 0.59
# - [x]  Исследована метрика *AUC-ROC*

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <h2><b>Общий вывод по проекту</b></h2>
#
# Ты очень постаралась, спасибо тебе за такую работу!)
#
# В ходе проекта были выполнены все этапы проекта, главная цель достигнута. Конечно присутствует ряд моментов, которые необходимо рассмотреть, но ничего страшного, для это я здесь). Давай пройдемся по всему что ты сделала, чтобы понять что надо сделать для того, чтобы проект был засчитан:
#
# - auc_roc метрика отсутствует - добавь
# - отсутствует перебор гиперпараметров - добавь его
# - используешь сразу по два метода: class_weight + upsample и class_weight + downsample - реализуй их по отдельности, так будет вернее!
# - Есть советы по проекту, если хочешь и есть время - реализуй их. Если нет, то запомни на будущее)
#
# `Отдельно прошу тебя рассмотреть совет с кодирование категориальных признаков - это очень важный момент. В следующих проектах, тебе проставят за такую реализацию минус`
#
# Работа классная, но нужно доработать! Удачи)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <h2><b>Общий вывод по проекту В2</b></h2>
#
# Все, проект можно принять - ты постаралась на славу!
